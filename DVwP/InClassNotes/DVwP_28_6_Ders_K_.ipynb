# %% [markdown]
# seaborn.pydata.org/tutorial

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

diamonds=sns.load_dataset('diamonds')
exercise=sns.load_dataset('exercise')
flights=sns.load_dataset('flights')
geyser=sns.load_dataset('geyser')
iris=sns.load_dataset('iris')
penguins=sns.load_dataset('penguins')
planets=sns.load_dataset('planets')
mpg=sns.load_dataset('mpg')
tips = sns.load_dataset('tips')
titanic=sns.load_dataset('titanic')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips["size"].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
# x ve y de mutlaka continuos numeric veri olmalı

# %%
sns.scatterplot(data=tips, x ="total_bill", y="tip")

# %%
sns.scatterplot(data=tips, x ="total_bill", y="tip"); #açıklamayı yoketmek için sonuna ; koyduk

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=tips, x ="total_bill", y="tip");

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=tips, x ="total_bill", y="tip", hue="smoker"); #hue'nin içerisine bir tane kategorik bir feature ekliyorum, 3. boyut katacak

# %%
# ayrı ayrı yapmak istersem

plt.figure(figsize=(10,5))
sns.scatterplot(data=tips[tips.smoker=="Yes"], x ="total_bill", y="tip");
#sadece Yesleri görüyorsun

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=tips[tips.smoker=="No"], x ="total_bill", y="tip");

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x=tips['total_bill'],y=tips['tip']);

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=tips, x="total_bill", y="tip", style="sex");
#style de kullanabilirsin ama hue daha çok tercih ediliyor

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=tips, x="total_bill", y="tip", style="sex", hue="sex"); 
# bu şekilde de kullanabilirsin

# %%
plt.figure(figsize=(10,5))
markers={"Male":">", "Female":"<"}
sns.scatterplot(data=tips, x="total_bill", y="tip", style="sex", hue="sex", s=150, markers=markers);

# %%
# https://matplotlib.org/stable/api/markers_api.html

# %%
plt.figure(figsize=(10,5))
markers={"Male":"*", "Female":","}
sns.scatterplot(data=tips, x="total_bill", y="tip", style="sex", hue="sex", s=150, markers=markers);

# %%
#sns.scatterplot(data=tips, x="total_bill", y="tip", style="sex", hue="sex")
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="day")

# %%
#iki grafiği yan yana çizmek istiyorsan matplot object oriented kullanacaksın
fig, ax = plt.subplots(1,2, figsize=(10,5))   #bir satır iki sütun- 1*2
sns.scatterplot(data=tips, x="total_bill", y="tip", style="sex", hue="sex", ax=ax[0])
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="day",ax=ax[1]);
#3 tane olsaydı 1,3 diyecektik, ax'ı da 2 olacaktı

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=tips, x ="total_bill", y="tip", hue="smoker", palette="viridis");
#palette renkleri değiştiriyor

# %% [markdown]
# #'viridis', 'plasma', 'inferno', 'magma', 'cividis'

# %%
# https://seaborn.pydata.org/tutorial/color_palettes.html
# https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=tips, x ="total_bill", y="tip", hue="smoker", palette="plasma");

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=tips, x ="total_bill", y="tip", hue="smoker", size="sex" ,palette="plasma");
#renk olarak smoker'ı gösterdik, size olarak da cinsiyeti gösterdik

#ama iç içe kullanmak çok etkin değil, anlaşılmıyor

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=tips, x ="total_bill", y="tip", alpha=0.7, size="sex");
#alpha 0 ile 1 arasında değer alır
#alpha biraz daha flue'laştırıyor

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=tips, x ="total_bill", y="tip", s=100);
# s ile her bir noktanın boyutunu değiştirebiliriz

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=tips, x ="total_bill", y="tip", s=300);

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=tips, x ="total_bill", y="tip", s=300, hue="sex");

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=tips, x ="total_bill", y="tip", s=300, hue="sex",alpha=0.7);

# %%
#SCATTER PLOT BU KADAR
# özelliği x ve y ekseninde numeric yani sayısal veri kullanmamız lazım, kategorik olmaz

# %%
# rugplot çok kullanılan bir plot değil, yadımcı olarak kullanılıyor

# %%
mpg
# Out:
#       mpg  cylinders  ...  origin                       name
# 0    18.0          8  ...     usa  chevrolet chevelle malibu
# 1    15.0          8  ...     usa          buick skylark 320
# 2    18.0          8  ...     usa         plymouth satellite
# 3    16.0          8  ...     usa              amc rebel sst
# 4    17.0          8  ...     usa                ford torino
# ..    ...        ...  ...     ...                        ...
# 393  27.0          4  ...     usa            ford mustang gl
# 394  44.0          4  ...  europe                  vw pickup
# 395  32.0          4  ...     usa              dodge rampage
# 396  28.0          4  ...     usa                ford ranger
# 397  31.0          4  ...     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %%
sns.rugplot(data=mpg, x="weight");

#seaborn her zaman data frame ile açlışır
#matpllot'ta array koyuyorduk, orası tek boyutlu olduğu için sadece x'i tanımlıyoruz, seaborn'da x ve y tanımlıyoruz

# %%
sns.rugplot(data=mpg, x="weight", height=0.5);
# y ekseni bir şey ifade etmiyor
# weight 1500'den 5000'e kdar gidiyor, bazı yerlerde yoğunlaşıyor
# height 0 ile 1 arasında yer alıyor

# %%
#displot: aslında histogram

# %%
sns.displot(data=mpg, x="weight");
#displot kendisi bir canvastır, figurdur. 2*2 grafşk yapacaksan displotla yapamazsın
# udemy de portilla kullanılmıyor diye uyarıyordu distplot için

# %%
sns.histplot(data=mpg, x="weight")

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,5))
sns.scatterplot(data=tips, x ="total_bill", y="tip", s=300, hue="sex", ax=ax[0])
sns.histplot(data=mpg, x="weight", ax=ax[1]);

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,5))
sns.scatterplot(data=tips, x ="total_bill", y="tip", s=300, hue="sex", ax=ax[0])
sns.displot(data=mpg, x="weight", ax=ax[1]);
#displot çalışmadı, ayrı verdi çünkü displot axis'e girmez !!!! en önemli fark
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.displot(data=mpg, x="weight", kind="hist") #displot histplottan daha yetenekli, kind var
#displot default olarak histogram çizer ama sadece hist çizmez, başka şekilde de çizer. örneğim

# %%
sns.displot(data=mpg, x="weight", kind="kde"); # bie de ecdf var
#içerinin alanı her zaman 1'e eşit

# %%
sns.displot(data=mpg, x="weight", kind="ecdf") #kümülatif olarak gidior, çok kullanılmıyor

# %%
sns.displot(data=mpg, x="weight", kde=True);
#histogramın üstüne kdeplot çiziyor. kde'nin default'u False

# %%
sns.displot(data=mpg, x="weight", kde=True, aspect=2); #boyutu aspect ile değişyor. 1.56 şeklinde de kullanabilirsin

# %%
sns.displot(data=mpg, x="weight", kde=False, aspect=1.5);

# %%
sns.displot(data=mpg, x="weight", kind="kde", aspect=1.5);

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=mpg, x="weight");

# %%
# plt.figure(figsize=(10,5)) defult değeri 6,4
sns.histplot(data=mpg, x="weight");

# %%
# grafiği dışarı atmak için
#fig.savefig("output.png")

# %%
plt.figure(figsize=(6,4))
sns.histplot(data=mpg, x="weight", bins=20); #10 bins vardı, 20'ye arttırdık

# %%
plt.figure(figsize=(6,4))
sns.histplot(data=mpg, x="weight", bins=50);

# %%
# wieght sütununu 1*2 şeklinde bir canvasta gösterellim, birinde rugplot, diğerinde histplot

plt.subplot(1,2,1)
sns.rugplot(data = mpg, x = 'weight')
plt.subplot(1,2,2)
sns.histplot(data = mpg, x = 'weight', kde = True);

# %%
fig, ax=plt.subplots(1,2)
sns.rugplot(data=mpg, x='weight',ax=ax[0], height=0.6)
sns.histplot(data=mpg, x='weight',kde=True,ax=ax[1])

# %%
sns.set(style="darkgrid")
sns.histplot(data = mpg, x = "weight", kde=True);

# %%
sns.set(style="dark")
sns.histplot(data = mpg, x = "weight", kde=True);

# %%
sns.set(style="whitegrid")
sns.histplot(data = mpg, x = "weight", kde=True);

# %%
# #darkgrid, whitegrid, dark, white, ticks

# %%
#barlara rakamları yazmak için dendi
for index,data in enumerate(age):
    ax.text(x=index , y =data+1,s=f"{data}" ,horizontalalignment='center')
# age yerine hangi data ise o yazılacak
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-2ba5a45956cc> in <module>()
#       1 #barlara rakamları yazmak için dendi
# ----> 2 for index,data in enumerate(age):
#       3     ax.text(x=index , y =data+1,s=f"{data}" ,horizontalalignment='center')
#       4 # age yerine hangi data ise o yazılacak
#
# NameError: name 'age' is not defined

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1  ...              181.0       3750.0    Male
# 1  Adelie  Torgersen            39.5  ...              186.0       3800.0  Female
# 2  Adelie  Torgersen            40.3  ...              195.0       3250.0  Female
# 3  Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4  Adelie  Torgersen            36.7  ...              193.0       3450.0  Female
#
# [5 rows x 7 columns]

# %%
sns.kdeplot(data=penguins, x="body_mass_g");

# %%
sns.kdeplot(data=penguins, x="body_mass_g", hue="sex");

# %%
sns.kdeplot(data=penguins, x="body_mass_g", hue="sex", shade=True);
#2900'un altında male yok

# %%
sns.kdeplot(data=penguins, x="bill_length_mm", hue="sex", shade=True);

# %%
#sadece x ekseninin çizdik, 2 boyutlu kde istesek nasıl olurdu?
sns.kdeplot(data=tips, x="total_bill", y="tip");

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip");

# %%
sns.kdeplot(data=tips, x="total_bill", y="tip",color="red");

# %%
sns.kdeplot(data=tips, x="total_bill", y="tip",color="red",shade=True);

# %%
#hadi yan yana koyalım
fig, ax=plt.subplots(1,2,figsize=(12,7))
sns.scatterplot(data=tips, x="total_bill", y="tip", ax=ax[0])

sns.kdeplot(data=tips, x="total_bill", y="tip",color="red",shade=True, ax=ax[1]);

# %%
#hadi sharey( share y axis) ekleyelim
fig, ax=plt.subplots(1,2,figsize=(12,7), sharey="row")
sns.scatterplot(data=tips, x="total_bill", y="tip", ax=ax[0], )

sns.kdeplot(data=tips, x="total_bill", y="tip",color="red",shade=True, ax=ax[1]);

# %%
#Üsttekiyle aynı
fig, ax=plt.subplots(1,2,figsize=(12,7), sharey=True)
sns.scatterplot(data=tips, x="total_bill", y="tip", ax=ax[0], )

sns.kdeplot(data=tips, x="total_bill", y="tip",color="red",shade=True, ax=ax[1]);

# %%
#############

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1  ...              181.0       3750.0    Male
# 1  Adelie  Torgersen            39.5  ...              186.0       3800.0  Female
# 2  Adelie  Torgersen            40.3  ...              195.0       3250.0  Female
# 3  Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4  Adelie  Torgersen            36.7  ...              193.0       3450.0  Female
#
# [5 rows x 7 columns]

# %%
sns.displot(data=penguins,
            x="body_mass_g",
            bins=10,
            rug=True,
            kde=True);
# 3 grafik üst üste, histogram, rug, kde

# %% [markdown]
# (https://seaborn.pydata.org/examples/index.html)

# %% [markdown]
# #Jointplot

# %%
sns.jointplot(data=tips, x="total_bill", y="tip", kind="scatter");
#scatter plot çiziyor, x ve y'ye histogramlarını ekliyor

# %%
sns.jointplot(data=tips, x="total_bill", y="tip", 
              #kind="scatter"
              );

# %%
# kind : { "scatter" | "kde" | "hist" | "hex" | "reg" | "resid" }

# %%
sns.jointplot(data=tips, x="total_bill", y="tip", 
              kind="kde"
              );

# data bu noktada yoğunlaşıyor ( 10 civarı)

# %%
sns.jointplot(data=tips, x="total_bill", y="tip", 
              kind="hist"
              );

# %%
sns.jointplot(data=tips, x="total_bill", y="tip", 
              kind="hex"
              );

# %%
mpg.head() #mile per galoon
# Out:
#     mpg  cylinders  displacement  ...  model_year  origin                       name
# 0  18.0          8         307.0  ...          70     usa  chevrolet chevelle malibu
# 1  15.0          8         350.0  ...          70     usa          buick skylark 320
# 2  18.0          8         318.0  ...          70     usa         plymouth satellite
# 3  16.0          8         304.0  ...          70     usa              amc rebel sst
# 4  17.0          8         302.0  ...          70     usa                ford torino
#
# [5 rows x 9 columns]

# %%
sns.jointplot(data=mpg, x="mpg", y="horsepower", 
              kind="scatter"
              );
