# %%
import numpy as np
import pandas as pd

import scipy.stats as stats

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Advertising.csv')
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True);

# %%
def plot_relation(df, target_var):
    num_cols = df.columns
    for col in num_cols:
        if col != target_var:
            plt.figure()
            sns.lmplot(x=col, y=target_var, data=df, height=7)
            plt.xlabel(f"variable name: {col}")
            plt.ylabel("Sales")

# %%
plot_relation(df, "sales");  # shaded area : confidence interval

# %%
def check_dist(df,var):
    plt.figure(figsize=(12,5))
    plt.subplot(1, 2, 1)
    sns.histplot(x=var, data = df)
    plt.subplot(1, 2, 2)
    stats.probplot(df[var], dist = 'norm', plot=plt)
    plt.show()

# %%
for col in df.drop('sales', axis=1).columns:
    check_dist(df,col)

# %%
df["total_spend"] = df["TV"] + df["radio"] + df["newspaper"]

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales  total_spend
# 0  230.1   37.8       69.2   22.1        337.1
# 1   44.5   39.3       45.1   10.4        128.9
# 2   17.2   45.9       69.3    9.3        132.4
# 3  151.5   41.3       58.5   18.5        251.3
# 4  180.8   10.8       58.4   12.9        250.0

# %%
corr = df["sales"].corr(df["total_spend"])

# %%
corr
# Out:
# 0.8677123027017427

# %%
plt.figure(figsize=(10,6))
sns.regplot(x="total_spend", y="sales", data=df, ci=None, label=f"Correlation: {corr}")
plt.legend();

# %% [markdown]
# R2 score
# The coefficient of determination, R2, is used to analyze how differences in one variable can be explained by a difference in a second variable(one variable = feature, second variable=target

# %%
R2_score = corr ** 2

# %%
R2_score
# Out:
# 0.7529246402599608

# %%
# y = mx + b

# %%
X = df["total_spend"]
y = df["sales"]

# %%
X_mat = np.vstack([X, np.ones(len(X))]).T

# %%
X_mat
# Out:
# array([[337.1,   1. ],
#        [128.9,   1. ],
#        [132.4,   1. ],
#        [251.3,   1. ],
#        [250. ,   1. ],
#        [132.6,   1. ],
#        [113.8,   1. ],
#        [151.4,   1. ],
#        [ 11.7,   1. ],
#        [223.6,   1. ],
#        [ 96.1,   1. ],
#        [242.7,   1. ],
#        [124.8,   1. ],
#        [112.3,   1. ],
#        [283. ,   1. ],
#        [296. ,   1. ],
#        [218.4,   1. ],
#        [376.8,   1. ],
#        [108. ,   1. ],
#        [190.3,   1. ],
#        [299.5,   1. ],
#        [266. ,   1. ],
#        [ 78.7,   1. ],
#        [271.4,   1. ],
#        [ 93.2,   1. ],
#        [285.9,   1. ],
#        [184.8,   1. ],
#        [279.7,   1. ],
#        [298.8,   1. ],
#        [127.4,   1. ],
#        [364.4,   1. ],
#        [168.9,   1. ],
#        [128.7,   1. ],
#        [285.9,   1. ],
#        [104.5,   1. ],
#        [303.3,   1. ],
#        [315.7,   1. ],
#        [169.8,   1. ],
#        [104.9,   1. ],
#        [297.7,   1. ],
#        [256.4,   1. ],
#        [249.1,   1. ],
#        [323.1,   1. ],
#        [241.7,   1. ],
#        [ 94.1,   1. ],
#        [229.1,   1. ],
#        [135.3,   1. ],
#        [299.9,   1. ],
#        [292.9,   1. ],
#        [115.4,   1. ],
#        [237.5,   1. ],
#        [113.6,   1. ],
#        [297.7,   1. ],
#        [287.5,   1. ],
#        [307.4,   1. ],
#        [308.3,   1. ],
#        [ 76.8,   1. ],
#        [172. ,   1. ],
#        [298.1,   1. ],
#        [249.5,   1. ],
#        [ 76.9,   1. ],
#        [358.7,   1. ],
#        [282.1,   1. ],
#        [140.7,   1. ],
#        [202.8,   1. ],
#        [ 79.2,   1. ],
#        [ 58.3,   1. ],
#        [164. ,   1. ],
#        [275.9,   1. ],
#        [287.9,   1. ],
#        [268.4,   1. ],
#        [155.8,   1. ],
#        [ 79.1,   1. ],
#        [166.4,   1. ],
#        [251.1,   1. ],
#        [150. ,   1. ],
#        [ 49.8,   1. ],
#        [163.2,   1. ],
#        [ 44.7,   1. ],
#        [146.8,   1. ],
#        [125.4,   1. ],
#        [280.8,   1. ],
#        [128.1,   1. ],
#        [148.5,   1. ],
#        [290.3,   1. ],
#        [277.3,   1. ],
#        [119.8,   1. ],
#        [214.5,   1. ],
#        [187.2,   1. ],
#        [209. ,   1. ],
#        [148.5,   1. ],
#        [ 63.1,   1. ],
#        [310.2,   1. ],
#        [359.7,   1. ],
#        [132.3,   1. ],
#        [247.8,   1. ],
#        [207. ,   1. ],
#        [227.9,   1. ],
#        [383.2,   1. ],
#        [222.8,   1. ],
#        [276.5,   1. ],
#        [433.6,   1. ],
#        [311.7,   1. ],
#        [223. ,   1. ],
#        [277.8,   1. ],
#        [243.3,   1. ],
#        [ 65.7,   1. ],
#        [113.9,   1. ],
#        [ 39.1,   1. ],
#        [287.8,   1. ],
#        [290.5,   1. ],
#        [302.9,   1. ],
#        [193.5,   1. ],
#        [240.9,   1. ],
#        [159.5,   1. ],
#        [162.8,   1. ],
#        [179.1,   1. ],
#        [ 92. ,   1. ],
#        [241.8,   1. ],
#        [ 57.7,   1. ],
#        [214.3,   1. ],
#        [ 90.9,   1. ],
#        [242. ,   1. ],
#        [170.1,   1. ],
#        [336. ,   1. ],
#        [124.9,   1. ],
#        [ 97.3,   1. ],
#        [ 89.4,   1. ],
#        [272.5,   1. ],
#        [114.7,   1. ],
#        [ 49. ,   1. ],
#        [311.1,   1. ],
#        [ 37.7,   1. ],
#        [298.4,   1. ],
#        [141.1,   1. ],
#        [103.8,   1. ],
#        [ 73.9,   1. ],
#        [362.3,   1. ],
#        [ 89.4,   1. ],
#        [230.5,   1. ],
#        [103.3,   1. ],
#        [304.7,   1. ],
#        [291.6,   1. ],
#        [144.7,   1. ],
#        [149.9,   1. ],
#        [151.2,   1. ],
#        [256.1,   1. ],
#        [336.5,   1. ],
#        [ 90.2,   1. ],
#        [ 91.1,   1. ],
#        [331.6,   1. ],
#        [178.1,   1. ],
#        [235.1,   1. ],
#        [248.7,   1. ],
#        [218.4,   1. ],
#        [ 21.4,   1. ],
#        [187.9,   1. ],
#        [175.4,   1. ],
#        [ 93.8,   1. ],
#        [184.7,   1. ],
#        [221.3,   1. ],
#        [170.8,   1. ],
#        [232.1,   1. ],
#        [207.7,   1. ],
#        [137.3,   1. ],
#        [322.7,   1. ],
#        [ 77.1,   1. ],
#        [231.4,   1. ],
#        [296.6,   1. ],
#        [301.3,   1. ],
#        [ 80. ,   1. ],
#        [232.8,   1. ],
#        [ 56.7,   1. ],
#        [188.3,   1. ],
#        [238.9,   1. ],
#        [367.6,   1. ],
#        [298.9,   1. ],
#        [213.2,   1. ],
#        [302.7,   1. ],
#        [193.2,   1. ],
#        [167.5,   1. ],
#        [251.3,   1. ],
#        [ 91.6,   1. ],
#        [402.4,   1. ],
#        [305.1,   1. ],
#        [269.7,   1. ],
#        [168.2,   1. ],
#        [238. ,   1. ],
#        [303.6,   1. ],
#        [ 54.2,   1. ],
#        [ 86.4,   1. ],
#        [ 92.3,   1. ],
#        [ 52.9,   1. ],
#        [212.4,   1. ],
#        [191.3,   1. ],
#        [ 55.7,   1. ],
#        [107.2,   1. ],
#        [192.7,   1. ],
#        [391.8,   1. ],
#        [249.4,   1. ]])

# %%
np.linalg.lstsq(X_mat, y, rcond=None) # m: 0.04868788, slope  4.24302822:intercept
# Out:
# (array([0.04868788, 4.24302822]),
#  array([1338.44397617]),
#  2,
#  array([3128.85849135,    5.92883485]))

# %%
m, c = np.linalg.lstsq(X_mat, y, rcond=None)[0]

# %%
m, c
# Out:
# (0.04868787931904815, 4.243028216036325)

# %%
#second method

# %%
np.polyfit(X,y, deg=1)
# Out:
# array([0.04868788, 4.24302822])

# %%
b1 = np.polyfit(X, y, deg = 1)[0]
b0 = np.polyfit(X, y, deg = 1)[1]
predict = b1*X + b0

# %%
# y = b1x + b0

# %%
values = {"actuel":y, "predicted":predict, "residual":y-predict, "LSE":(y-predict)**2}

# %%
df_2 = pd.DataFrame(values)
df_2
# Out:
#      actuel  predicted  residual        LSE
# 0      22.1  20.655712  1.444288   2.085967
# 1      10.4  10.518896 -0.118896   0.014136
# 2       9.3  10.689303 -1.389303   1.930164
# 3      18.5  16.478292  2.021708   4.087302
# 4      12.9  16.414998 -3.514998  12.355211
# ..      ...        ...       ...        ...
# 195     7.6   6.954943  0.645057   0.416098
# 196     9.7   9.462369  0.237631   0.056469
# 197    12.8  13.625183 -0.825183   0.680926
# 198    25.5  23.318939  2.181061   4.757026
# 199    13.4  16.385785 -2.985785   8.914914
#
# [200 rows x 4 columns]

# %%
np.sum(df_2['residual'])
# Out:
# 8.810729923425242e-13

# %%
plt.figure(figsize=(10,6))
sns.distplot(df_2["residual"], fit=stats.norm)
# Out:
# C:\Users\erdem\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='residual', ylabel='Density'>
